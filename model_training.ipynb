# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: altair==4.2.2 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from -r requirements.txt (line 1)) (4.2.2)
# Requirement already satisfied: imbalanced-learn==0.11.0 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from -r requirements.txt (line 2)) (0.11.0)
# Requirement already satisfied: pillow==10.4.0 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from -r requirements.txt (line 3)) (10.4.0)
# Requirement already satisfied: pip-chill==1.0.3 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from -r requirements.txt (line 4)) (1.0.3)
# Requirement already satisfied: pipreqs==0.5.0 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from -r requirements.txt (line 5)) (0.5.0)
# Requirement already satisfied: protobuf==4.25.3 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from -r requirements.txt (line 6)) (4.25.3)
# Requirement already satisfied: pyarrow==16.1.0 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from -r requirements.txt (line 7)) (16.1.0)
# Requirement already satisfied: pydeck==0.8.0b4 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from -r requirements.txt (line 8)) (0.8.0b4)
# Requirement already satisfied: rich==13.9.3 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from -r requirements.txt (line 9)) (13.9.3)
# Requirement already satisfied: tenacity==8.5.0 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from -r requirements.txt (line 10)) (8.5.0)
# Requirement already satisfied: ucimlrepo==0.0.7 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from -r requirements.txt (line 11)) (0.0.7)
# Requirement already satisfied: xgboost==2.1.1 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from -r requirements.txt (line 12)) (2.1.1)
# Requirement already satisfied: scikit-learn==1.3.2 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from -r requirements.txt (line 13)) (1.3.2)
# Requirement already satisfied: jsonschema>=3.0 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from altair==4.2.2->-r requirements.txt (line 1)) (3.2.0)
# Requirement already satisfied: pandas>=0.18 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from altair==4.2.2->-r requirements.txt (line 1)) (1.1.3)
# Requirement already satisfied: toolz in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from altair==4.2.2->-r requirements.txt (line 1)) (0.11.1)
# Requirement already satisfied: numpy in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from altair==4.2.2->-r requirements.txt (line 1)) (1.21.0)
# Requirement already satisfied: jinja2 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from altair==4.2.2->-r requirements.txt (line 1)) (3.1.4)
# Requirement already satisfied: entrypoints in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from altair==4.2.2->-r requirements.txt (line 1)) (0.3)
# Requirement already satisfied: joblib>=1.1.1 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from imbalanced-learn==0.11.0->-r requirements.txt (line 2)) (1.4.2)
# Requirement already satisfied: scipy>=1.5.0 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from imbalanced-learn==0.11.0->-r requirements.txt (line 2)) (1.5.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from imbalanced-learn==0.11.0->-r requirements.txt (line 2)) (2.1.0)
# Requirement already satisfied: yarg==0.1.9 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from pipreqs==0.5.0->-r requirements.txt (line 5)) (0.1.9)
# Requirement already satisfied: ipython==8.12.3 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from pipreqs==0.5.0->-r requirements.txt (line 5)) (8.12.3)
# Requirement already satisfied: docopt==0.6.2 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from pipreqs==0.5.0->-r requirements.txt (line 5)) (0.6.2)
# Requirement already satisfied: nbconvert<8.0.0,>=7.11.0 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from pipreqs==0.5.0->-r requirements.txt (line 5)) (7.16.4)
# Requirement already satisfied: typing-extensions<5.0,>=4.0.0 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from rich==13.9.3->-r requirements.txt (line 9)) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from rich==13.9.3->-r requirements.txt (line 9)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from rich==13.9.3->-r requirements.txt (line 9)) (2.18.0)
# Requirement already satisfied: certifi>=2020.12.5 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from ucimlrepo==0.0.7->-r requirements.txt (line 11)) (2024.8.30)
# Requirement already satisfied: appnope in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from ipython==8.12.3->pipreqs==0.5.0->-r requirements.txt (line 5)) (0.1.0)
# Requirement already satisfied: matplotlib-inline in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from ipython==8.12.3->pipreqs==0.5.0->-r requirements.txt (line 5)) (0.1.7)
# Requirement already satisfied: jedi>=0.16 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from ipython==8.12.3->pipreqs==0.5.0->-r requirements.txt (line 5)) (0.17.1)
# Requirement already satisfied: backcall in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from ipython==8.12.3->pipreqs==0.5.0->-r requirements.txt (line 5)) (0.2.0)
# Requirement already satisfied: decorator in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from ipython==8.12.3->pipreqs==0.5.0->-r requirements.txt (line 5)) (4.4.2)
# Requirement already satisfied: pexpect>4.3 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from ipython==8.12.3->pipreqs==0.5.0->-r requirements.txt (line 5)) (4.8.0)
# Requirement already satisfied: pickleshare in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from ipython==8.12.3->pipreqs==0.5.0->-r requirements.txt (line 5)) (0.7.5)
# Requirement already satisfied: stack-data in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from ipython==8.12.3->pipreqs==0.5.0->-r requirements.txt (line 5)) (0.6.3)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from ipython==8.12.3->pipreqs==0.5.0->-r requirements.txt (line 5)) (3.0.48)
# Requirement already satisfied: traitlets>=5 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from ipython==8.12.3->pipreqs==0.5.0->-r requirements.txt (line 5)) (5.14.3)
# Requirement already satisfied: requests in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from yarg==0.1.9->pipreqs==0.5.0->-r requirements.txt (line 5)) (2.24.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from jedi>=0.16->ipython==8.12.3->pipreqs==0.5.0->-r requirements.txt (line 5)) (0.7.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from jinja2->altair==4.2.2->-r requirements.txt (line 1)) (2.1.5)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from jsonschema>=3.0->altair==4.2.2->-r requirements.txt (line 1)) (0.17.3)
# Requirement already satisfied: attrs>=17.4.0 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from jsonschema>=3.0->altair==4.2.2->-r requirements.txt (line 1)) (20.3.0)
# Requirement already satisfied: setuptools in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from jsonschema>=3.0->altair==4.2.2->-r requirements.txt (line 1)) (50.3.1.post20201107)
# Requirement already satisfied: six>=1.11.0 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from jsonschema>=3.0->altair==4.2.2->-r requirements.txt (line 1)) (1.15.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from markdown-it-py>=2.2.0->rich==13.9.3->-r requirements.txt (line 9)) (0.1.2)
# Requirement already satisfied: packaging in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from nbconvert<8.0.0,>=7.11.0->pipreqs==0.5.0->-r requirements.txt (line 5)) (20.4)
# Requirement already satisfied: defusedxml in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from nbconvert<8.0.0,>=7.11.0->pipreqs==0.5.0->-r requirements.txt (line 5)) (0.6.0)
# Requirement already satisfied: jupyterlab-pygments in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from nbconvert<8.0.0,>=7.11.0->pipreqs==0.5.0->-r requirements.txt (line 5)) (0.1.2)
# Requirement already satisfied: tinycss2 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from nbconvert<8.0.0,>=7.11.0->pipreqs==0.5.0->-r requirements.txt (line 5)) (1.4.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from nbconvert<8.0.0,>=7.11.0->pipreqs==0.5.0->-r requirements.txt (line 5)) (1.4.3)
# Requirement already satisfied: bleach!=5.0.0 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from nbconvert<8.0.0,>=7.11.0->pipreqs==0.5.0->-r requirements.txt (line 5)) (3.2.1)
# Requirement already satisfied: importlib-metadata>=3.6 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from nbconvert<8.0.0,>=7.11.0->pipreqs==0.5.0->-r requirements.txt (line 5)) (8.5.0)
# Requirement already satisfied: beautifulsoup4 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from nbconvert<8.0.0,>=7.11.0->pipreqs==0.5.0->-r requirements.txt (line 5)) (4.9.3)
# Requirement already satisfied: nbformat>=5.7 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from nbconvert<8.0.0,>=7.11.0->pipreqs==0.5.0->-r requirements.txt (line 5)) (5.10.4)
# Requirement already satisfied: jupyter-core>=4.7 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from nbconvert<8.0.0,>=7.11.0->pipreqs==0.5.0->-r requirements.txt (line 5)) (5.7.2)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from nbconvert<8.0.0,>=7.11.0->pipreqs==0.5.0->-r requirements.txt (line 5)) (0.5.1)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from nbconvert<8.0.0,>=7.11.0->pipreqs==0.5.0->-r requirements.txt (line 5)) (3.0.2)
# Requirement already satisfied: webencodings in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from bleach!=5.0.0->nbconvert<8.0.0,>=7.11.0->pipreqs==0.5.0->-r requirements.txt (line 5)) (0.5.1)
# Requirement already satisfied: zipp>=3.20 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from importlib-metadata>=3.6->nbconvert<8.0.0,>=7.11.0->pipreqs==0.5.0->-r requirements.txt (line 5)) (3.20.2)
# Requirement already satisfied: platformdirs>=2.5 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from jupyter-core>=4.7->nbconvert<8.0.0,>=7.11.0->pipreqs==0.5.0->-r requirements.txt (line 5)) (4.3.6)
# Requirement already satisfied: jupyter-client>=6.1.5 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from nbclient>=0.5.0->nbconvert<8.0.0,>=7.11.0->pipreqs==0.5.0->-r requirements.txt (line 5)) (6.1.7)
# Requirement already satisfied: async-generator in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from nbclient>=0.5.0->nbconvert<8.0.0,>=7.11.0->pipreqs==0.5.0->-r requirements.txt (line 5)) (1.10)
# Requirement already satisfied: nest-asyncio in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from nbclient>=0.5.0->nbconvert<8.0.0,>=7.11.0->pipreqs==0.5.0->-r requirements.txt (line 5)) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.1 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from jupyter-client>=6.1.5->nbclient>=0.5.0->nbconvert<8.0.0,>=7.11.0->pipreqs==0.5.0->-r requirements.txt (line 5)) (2.8.1)
# Requirement already satisfied: tornado>=4.1 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from jupyter-client>=6.1.5->nbclient>=0.5.0->nbconvert<8.0.0,>=7.11.0->pipreqs==0.5.0->-r requirements.txt (line 5)) (6.0.4)
# Requirement already satisfied: pyzmq>=13 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from jupyter-client>=6.1.5->nbclient>=0.5.0->nbconvert<8.0.0,>=7.11.0->pipreqs==0.5.0->-r requirements.txt (line 5)) (19.0.2)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from nbformat>=5.7->nbconvert<8.0.0,>=7.11.0->pipreqs==0.5.0->-r requirements.txt (line 5)) (2.20.0)
# Requirement already satisfied: pytz>=2017.2 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.18->altair==4.2.2->-r requirements.txt (line 1)) (2020.1)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from pexpect>4.3->ipython==8.12.3->pipreqs==0.5.0->-r requirements.txt (line 5)) (0.6.0)
# Requirement already satisfied: wcwidth in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython==8.12.3->pipreqs==0.5.0->-r requirements.txt (line 5)) (0.2.5)
# Requirement already satisfied: soupsieve>1.2 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from beautifulsoup4->nbconvert<8.0.0,>=7.11.0->pipreqs==0.5.0->-r requirements.txt (line 5)) (2.0.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from packaging->nbconvert<8.0.0,>=7.11.0->pipreqs==0.5.0->-r requirements.txt (line 5)) (2.4.7)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from requests->yarg==0.1.9->pipreqs==0.5.0->-r requirements.txt (line 5)) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from requests->yarg==0.1.9->pipreqs==0.5.0->-r requirements.txt (line 5)) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from requests->yarg==0.1.9->pipreqs==0.5.0->-r requirements.txt (line 5)) (2.10)
# Requirement already satisfied: executing>=1.2.0 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from stack-data->ipython==8.12.3->pipreqs==0.5.0->-r requirements.txt (line 5)) (2.1.0)
# Requirement already satisfied: pure-eval in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from stack-data->ipython==8.12.3->pipreqs==0.5.0->-r requirements.txt (line 5)) (0.2.3)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/franciso/opt/anaconda3/lib/python3.8/site-packages (from stack-data->ipython==8.12.3->pipreqs==0.5.0->-r requirements.txt (line 5)) (2.4.1)
# WARNING: You are using pip version 21.1.3; however, version 24.3.1 is available.
# You should consider upgrading via the '/Users/franciso/opt/anaconda3/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
cdc_diabetes_health_indicators = fetch_ucirepo(id=891) 
  
# data (as pandas dataframes) 
X = cdc_diabetes_health_indicators.data.features 
y = cdc_diabetes_health_indicators.data.targets 
  
# metadata 
print(cdc_diabetes_health_indicators.metadata) 
  
# variable information 
print(cdc_diabetes_health_indicators.variables)
# Out:
# {'uci_id': 891, 'name': 'CDC Diabetes Health Indicators', 'repository_url': 'https://archive.ics.uci.edu/dataset/891/cdc+diabetes+health+indicators', 'data_url': 'https://archive.ics.uci.edu/static/public/891/data.csv', 'abstract': 'The Diabetes Health Indicators Dataset contains healthcare statistics and lifestyle survey information about people in general along with their diagnosis of diabetes. The 35 features consist of some demographics, lab test results, and answers to survey questions for each patient. The target variable for classification is whether a patient has diabetes, is pre-diabetic, or healthy. ', 'area': 'Health and Medicine', 'tasks': ['Classification'], 'characteristics': ['Tabular', 'Multivariate'], 'num_instances': 253680, 'num_features': 21, 'feature_types': ['Categorical', 'Integer'], 'demographics': ['Sex', 'Age', 'Education Level', 'Income'], 'target_col': ['Diabetes_binary'], 'index_col': ['ID'], 'has_missing_values': 'no', 'missing_values_symbol': None, 'year_of_dataset_creation': 2017, 'last_updated': 'Fri Nov 03 2023', 'dataset_doi': '10.24432/C53919', 'creators': [], 'intro_paper': {'ID': 308, 'type': 'NATIVE', 'title': 'Incidence of End-Stage Renal Disease Attributed to Diabetes Among Persons with Diagnosed Diabetes — United States and Puerto Rico, 2000–2014', 'authors': 'Nilka Rios Burrows, MPH; Israel Hora, PhD; Linda S. Geiss, MA; Edward W. Gregg, PhD; Ann Albright, PhD', 'venue': 'Morbidity and Mortality Weekly Report', 'year': 2017, 'journal': None, 'DOI': None, 'URL': 'https://www.cdc.gov/mmwr/volumes/66/wr/mm6643a2.htm', 'sha': None, 'corpus': None, 'arxiv': None, 'mag': None, 'acl': None, 'pmid': None, 'pmcid': None}, 'additional_info': {'summary': 'Dataset link: https://www.cdc.gov/brfss/annual_data/annual_2014.html', 'purpose': 'To better understand the relationship between  lifestyle and diabetes in the US', 'funded_by': 'The CDC', 'instances_represent': 'Each row represents a person participating in this study.', 'recommended_data_splits': 'Cross validation or a fixed train-test split could be used.', 'sensitive_data': '- Gender\n- Income\n- Education level', 'preprocessing_description': 'Bucketing of age', 'variable_info': '- Diabetes diagnosis\n- Demographics (race, sex)\n- Personal information (income, educations)\n- Health history (drinking, smoking, mental health, physical health)', 'citation': None}, 'external_url': 'https://www.kaggle.com/datasets/alexteboul/diabetes-health-indicators-dataset'}
#                     name     role     type      demographic  \
# 0                     ID       ID  Integer             None
# 1        Diabetes_binary   Target   Binary             None
# 2                 HighBP  Feature   Binary             None
# 3               HighChol  Feature   Binary             None
# 4              CholCheck  Feature   Binary             None
# 5                    BMI  Feature  Integer             None
# 6                 Smoker  Feature   Binary             None
# 7                 Stroke  Feature   Binary             None
# 8   HeartDiseaseorAttack  Feature   Binary             None
# 9           PhysActivity  Feature   Binary             None
# 10                Fruits  Feature   Binary             None
# 11               Veggies  Feature   Binary             None
# 12     HvyAlcoholConsump  Feature   Binary             None
# 13         AnyHealthcare  Feature   Binary             None
# 14           NoDocbcCost  Feature   Binary             None
# 15               GenHlth  Feature  Integer             None
# 16              MentHlth  Feature  Integer             None
# 17              PhysHlth  Feature  Integer             None
# 18              DiffWalk  Feature   Binary             None
# 19                   Sex  Feature   Binary              Sex
# 20                   Age  Feature  Integer              Age
# 21             Education  Feature  Integer  Education Level
# 22                Income  Feature  Integer           Income
#
#                                           description units missing_values
# 0                                          Patient ID  None             no
# 1         0 = no diabetes 1 = prediabetes or diabetes  None             no
# 2                          0 = no high BP 1 = high BP  None             no
# 3        0 = no high cholesterol 1 = high cholesterol  None             no
# 4   0 = no cholesterol check in 5 years 1 = yes ch...  None             no
# 5                                     Body Mass Index  None             no
# 6   Have you smoked at least 100 cigarettes in you...  None             no
# 7        (Ever told) you had a stroke. 0 = no 1 = yes  None             no
# 8   coronary heart disease (CHD) or myocardial inf...  None             no
# 9   physical activity in past 30 days - not includ...  None             no
# 10  Consume Fruit 1 or more times per day 0 = no 1...  None             no
# 11  Consume Vegetables 1 or more times per day 0 =...  None             no
# 12  Heavy drinkers (adult men having more than 14 ...  None             no
# 13  Have any kind of health care coverage, includi...  None             no
# 14  Was there a time in the past 12 months when yo...  None             no
# 15  Would you say that in general your health is: ...  None             no
# 16  Now thinking about your mental health, which i...  None             no
# 17  Now thinking about your physical health, which...  None             no
# 18  Do you have serious difficulty walking or clim...  None             no
# 19                                0 = female 1 = male  None             no
# 20  13-level age category (_AGEG5YR see codebook) ...  None             no
# 21  Education level (EDUCA see codebook) scale 1-6...  None             no
# 22  Income scale (INCOME2 see codebook) scale 1-8 ...  None             no

# %%
# what's the size of the dataset?
print(X.shape)
print(y.shape)
# Out:
# (253680, 21)
# (253680, 1)

# %%
# create a dataframe
import pandas as pd
df = pd.DataFrame(X)
df['Diabetes_binary'] = y
df.head()
# Out:
#    HighBP  HighChol  CholCheck  BMI  Smoker  Stroke  HeartDiseaseorAttack  \
# 0       1         1          1   40       1       0                     0
# 1       0         0          0   25       1       0                     0
# 2       1         1          1   28       0       0                     0
# 3       1         0          1   27       0       0                     0
# 4       1         1          1   24       0       0                     0
#
#    PhysActivity  Fruits  Veggies  ...  NoDocbcCost  GenHlth  MentHlth  \
# 0             0       0        1  ...            0        5        18
# 1             1       0        0  ...            1        3         0
# 2             0       1        0  ...            1        5        30
# 3             1       1        1  ...            0        2         0
# 4             1       1        1  ...            0        2         3
#
#    PhysHlth  DiffWalk  Sex  Age  Education  Income  Diabetes_binary
# 0        15         1    0    9          4       3                0
# 1         0         0    0    7          6       1                0
# 2        30         1    0    9          4       8                0
# 3         0         0    0   11          3       6                0
# 4         0         0    0   11          5       4                0
#
# [5 rows x 22 columns]

# %%
# save as csv
df.to_csv('./data/cdc_diabetes_health_indicators.csv', index=False)

# save as pickle
df.to_pickle('cdc_diabetes_health_indicators.pkl')

# %%
# no class weights or SMOTE
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import joblib

file_path = './data/cdc_diabetes_health_indicators.csv'
diabetes_data = pd.read_csv(file_path)

X = diabetes_data.drop('Diabetes_binary', axis=1)
y = diabetes_data['Diabetes_binary']

# the simple imputer fills in missing values with the mean
imputer = SimpleImputer(strategy='mean')
X_imputed = pd.DataFrame(imputer.fit_transform(X), columns=X.columns)

# prepare the training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_imputed, y, test_size=0.2, random_state=42)


scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# logistic regression model
logistic_model = LogisticRegression(max_iter=1000)
logistic_model.fit(X_train_scaled, y_train)

# make predictions
y_pred = logistic_model.predict(X_test_scaled)

# model evaluation
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

print("Accuracy:", accuracy)
print("\nConfusion Matrix:\n", conf_matrix)
print("\nClassification Report:\n", class_report)
# Out:
# Accuracy: 0.865874329864396
#
# Confusion Matrix:
#  [[42773   966]
#  [ 5839  1158]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.98      0.93     43739
#            1       0.55      0.17      0.25      6997
#
#     accuracy                           0.87     50736
#    macro avg       0.71      0.57      0.59     50736
# weighted avg       0.83      0.87      0.83     50736

# %%
joblib.dump(logistic_model, './models/logistic_regression_model.pkl')
joblib.dump(scaler, 'scaler.pkl')

print("Model and scaler saved successfully.")
# Out:
# Model and scaler saved successfully.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import ADASYN
import joblib

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Applying ADASYN to balance the classes in the training set
adasyn = ADASYN(random_state=42)
X_resampled, y_resampled = adasyn.fit_resample(X_train_scaled, y_train)

rf_model = RandomForestClassifier(
    n_estimators=100,
    max_depth=10,
    class_weight='balanced',
    random_state=42
)
rf_model.fit(X_resampled, y_resampled)

# save the model and scaler
joblib.dump(rf_model, './models/random_forest_diabetes_model.pkl')
joblib.dump(scaler, './models/scaler.pkl')

print("Model and scaler saved successfully.")
# Out:
# Model and scaler saved successfully.
